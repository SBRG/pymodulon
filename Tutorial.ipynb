# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Quickstart" data-toc-modified-id="Quickstart-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Quickstart</a></span></li><li><span><a href="#Initialize-your-IcaData-object" data-toc-modified-id="Initialize-your-IcaData-object-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Initialize your IcaData object</a></span><ul class="toc-item"><li><span><a href="#Minimum-requirements" data-toc-modified-id="Minimum-requirements-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Minimum requirements</a></span></li><li><span><a href="#Viewing-matrices" data-toc-modified-id="Viewing-matrices-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Viewing matrices</a></span></li><li><span><a href="#Sample,-gene,-and-iModulon-names" data-toc-modified-id="Sample,-gene,-and-iModulon-names-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Sample, gene, and iModulon names</a></span></li><li><span><a href="#Adding-the-X-matrix" data-toc-modified-id="Adding-the-X-matrix-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Adding the X matrix</a></span></li></ul></li><li><span><a href="#Sample,-gene,-and-iModulon-tables" data-toc-modified-id="Sample,-gene,-and-iModulon-tables-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Sample, gene, and iModulon tables</a></span><ul class="toc-item"><li><span><a href="#Loading-tables" data-toc-modified-id="Loading-tables-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Loading tables</a></span></li><li><span><a href="#Viewing-tables" data-toc-modified-id="Viewing-tables-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Viewing tables</a></span></li></ul></li><li><span><a href="#TRN-Table" data-toc-modified-id="TRN-Table-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>TRN Table</a></span><ul class="toc-item"><li><span><a href="#Load-the-TRN" data-toc-modified-id="Load-the-TRN-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Load the TRN</a></span></li></ul></li><li><span><a href="#iModulon-properties" data-toc-modified-id="iModulon-properties-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>iModulon properties</a></span><ul class="toc-item"><li><span><a href="#Inspecting-iModulons" data-toc-modified-id="Inspecting-iModulons-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Inspecting iModulons</a></span></li><li><span><a href="#Renaming-iModulons" data-toc-modified-id="Renaming-iModulons-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Renaming iModulons</a></span></li><li><span><a href="#Identifying-&quot;single-gene&quot;-iModulons" data-toc-modified-id="Identifying-&quot;single-gene&quot;-iModulons-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Identifying "single-gene" iModulons</a></span></li></ul></li><li><span><a href="#Gene-set-enrichment-analysis" data-toc-modified-id="Gene-set-enrichment-analysis-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Gene set enrichment analysis</a></span><ul class="toc-item"><li><span><a href="#General-functions" data-toc-modified-id="General-functions-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>General functions</a></span></li><li><span><a href="#Using-the-IcaData-object" data-toc-modified-id="Using-the-IcaData-object-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Using the IcaData object</a></span><ul class="toc-item"><li><span><a href="#Save-to-sample-table" data-toc-modified-id="Save-to-sample-table-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Save to sample table</a></span></li></ul></li></ul></li><li><span><a href="#iModulon-Thresholds" data-toc-modified-id="iModulon-Thresholds-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>iModulon Thresholds</a></span><ul class="toc-item"><li><span><a href="#Fitting-the-threshold" data-toc-modified-id="Fitting-the-threshold-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Fitting the threshold</a></span></li><li><span><a href="#Changing-the-D'agostino-statistic" data-toc-modified-id="Changing-the-D'agostino-statistic-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Changing the D'agostino statistic</a></span></li><li><span><a href="#Manually-changing-thresholds" data-toc-modified-id="Manually-changing-thresholds-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Manually changing thresholds</a></span></li></ul></li><li><span><a href="#Plotting" data-toc-modified-id="Plotting-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plotting</a></span><ul class="toc-item"><li><span><a href="#Bar-plots" data-toc-modified-id="Bar-plots-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Bar plots</a></span><ul class="toc-item"><li><span><a href="#Plot-Gene-Expression" data-toc-modified-id="Plot-Gene-Expression-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Plot Gene Expression</a></span></li><li><span><a href="#Plot-iModulon-Activities" data-toc-modified-id="Plot-iModulon-Activities-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>Plot iModulon Activities</a></span></li><li><span><a href="#Plot-sample-metadata" data-toc-modified-id="Plot-sample-metadata-8.1.3"><span class="toc-item-num">8.1.3&nbsp;&nbsp;</span>Plot sample metadata</a></span></li></ul></li><li><span><a href="#Scatterplots" data-toc-modified-id="Scatterplots-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Scatterplots</a></span><ul class="toc-item"><li><span><a href="#Compare-two-iModulon-activities" data-toc-modified-id="Compare-two-iModulon-activities-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Compare two iModulon activities</a></span></li></ul></li></ul></li></ul></div>

# %%
from pymodulon.core import IcaData
from pymodulon.visualization import *
from os.path import abspath, join
import pandas as pd

# %%
DATA_DIR = join('pymodulon', 'test', 'precise_data')

# %% [markdown]
# # Quickstart

# %%
M = join(DATA_DIR, 'M.csv')
A = join(DATA_DIR, 'A.csv')
X = join(DATA_DIR, 'X.csv')

gene_file = join(DATA_DIR, 'gene_table.csv')
sample_file = join(DATA_DIR, 'sample_table.csv')
imodulon_file = join(DATA_DIR, 'imodulon_table.csv')

trn = pd.read_csv(join(DATA_DIR, 'trn.csv'))

ica_data = IcaData(M,A,X,
                   gene_table=gene_file,
                   sample_table=sample_file,
                   imodulon_table=imodulon_file,
                   trn=trn,
                   dagostino_cutoff=550)

# %% [markdown]
# # Initialize your IcaData object

# %% [markdown]
# ## Minimum requirements
# The IcaData object only requires two matrices, the **M** and the **A** matrices. However, many functions (such as TRN enrichment) will be limited without including additional data.
# These matrices can be added as either a filename or a pandas DataFrame

# %%
M = join(DATA_DIR, 'M.csv')
A = join(DATA_DIR, 'A.csv')

# %%
ica_data = IcaData(M,A)

# %% [markdown]
# ## Viewing matrices
# You can directly view the M and A matrices

# %%
ica_data.A.head()
# Out:
#    control__wt_glc__1  control__wt_glc__2  fur__wt_dpd__1  fur__wt_dpd__2  \
# 0            0.076035           -0.076035        1.483992        1.719034
# 1           -0.408568            0.408568        1.760680        1.357274
# 2            0.103912           -0.103912        0.847276        1.530875
# 3           -0.456843            0.456843        5.890468        6.051415
# 4            0.269057           -0.269057       -0.254271        0.184537
#
#    fur__wt_fe__1  fur__wt_fe__2  fur__delfur_dpd__1  fur__delfur_dpd__2  \
# 0      -1.184220      -1.350203            1.451882            1.329577
# 1      -0.446482      -0.931725            0.517458            0.427993
# 2       0.258492       0.188903            1.232846            0.883215
# 3      -0.914670      -1.087245            5.210846            5.028641
# 4       0.651527       0.691914            0.016636           -0.465781
#
#    fur__delfur_fe2__1  fur__delfur_fe2__2  ...  efeU__menFentC_ale29__1  \
# ...

# %% [markdown]
# ## Sample, gene, and iModulon names
# If the M and A matrices have sample/gene/iModulon names, these will be saved as the official sample/gene/iModulon.

# %%
print('Gene names:',ica_data.gene_names[:5])
print('Sample names:',ica_data.sample_names[:5])
print('iModulon names:',ica_data.imodulon_names[:5])
# Out:
# Gene names: ['b0002', 'b0003', 'b0004', 'b0005', 'b0006']
# Sample names: ['control__wt_glc__1', 'control__wt_glc__2', 'fur__wt_dpd__1', 'fur__wt_dpd__2', 'fur__wt_fe__1']
# iModulon names: [0, 1, 2, 3, 4]

# %% [markdown]
# ## Adding the X matrix
# The **X** matrix contains expression data and is mainly used for plotting functions.

# %%
X = join(DATA_DIR, 'X.csv')

# %%
ica_data.X = X

# %% [markdown]
# # Sample, gene, and iModulon tables
# You may load in additional data tables with information about your samples, genes, or iModulons. If you do not load any data, these tables are originally empty but can be altered like any pandas table.

# %%
ica_data.gene_table.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [b0002, b0003, b0004, b0005, b0006]

# %%
ica_data.gene_table['gene_name'] = 'example'

# %%
ica_data.gene_table.head()
# Out:
#       gene_name
# b0002   example
# b0003   example
# b0004   example
# b0005   example
# b0006   example

# %% [markdown]
# ## Loading tables
# Sample/gene/iModulon tables contain one sample/gene/iModulon per row, and information about the respective item in columns.
# **The sample/gene/iModulon names must match the names in your M and A matrix.** However, the order of the names does not matter.
# The tables can be passed in using either a filename or a pandas DataFrame.

# %%
gene_file = join(DATA_DIR, 'gene_table.csv')
sample_file = join(DATA_DIR, 'sample_table.csv')
imodulon_file = join(DATA_DIR, 'imodulon_table.csv')
print('Gene file:',gene_file)
# Out:
# Gene file: pymodulon/test/precise_data/gene_table.csv

# %%
ica_data.gene_table = gene_file
ica_data.sample_table = sample_file
ica_data.imodulon_table = imodulon_file

# %% [markdown]
# ## Viewing tables

# %%
ica_data.sample_table.head()
# Out:
#                       study project_id condition_id  rep_id      contact  \
# control__wt_glc__1  Control    control       wt_glc       1  Sangwoo Seo
# control__wt_glc__2  Control    control       wt_glc       2  Sangwoo Seo
# fur__wt_dpd__1          Fur        fur       wt_dpd       1  Sangwoo Seo
# fur__wt_dpd__2          Fur        fur       wt_dpd       2  Sangwoo Seo
# fur__wt_fe__1           Fur        fur        wt_fe       1  Sangwoo Seo
#
#                    library creator  run_date            Strain Description  \
# control__wt_glc__1     Sangwoo Seo  04/17/13  Escherichia coli K-12 MG1655
# control__wt_glc__2     Sangwoo Seo  04/17/13  Escherichia coli K-12 MG1655
# fur__wt_dpd__1         Sangwoo Seo  10/02/13  Escherichia coli K-12 MG1655
# fur__wt_dpd__2         Sangwoo Seo  10/02/13  Escherichia coli K-12 MG1655
# fur__wt_fe__1          Sangwoo Seo  09/05/13  Escherichia coli K-12 MG1655
#
#                     Strain Base Media  ... Sequencing Machine  \
# ...

# %%
ica_data.gene_table.head()
# Out:
#        start  stop strand gene_name  length   operon  \
# b0002    336  2799      +      thrA    2463  thrLABC
# b0003   2800  3733      +      thrB     933  thrLABC
# b0004   3733  5020      +      thrC    1287  thrLABC
# b0005   5233  5530      +      yaaX     297     yaaX
# b0006   5682  6459      -      yaaA     777     yaaA
#
#                                        cog
# b0002  Amino acid transport and metabolism
# b0003  Amino acid transport and metabolism
# b0004  Amino acid transport and metabolism
# b0005                     Function unknown
# b0006                     Function unknown

# %%
ica_data.imodulon_table.head()
# Out:
#           name regulator  pvalue  qvalue  precision  recall  f1score   TP  \
# 0         YieP       NaN     NaN     NaN        NaN     NaN      NaN  NaN
# 1         GlpR      glpR     0.0     NaN        1.0     1.0      4.0  9.0
# 2         YgbI       NaN     NaN     NaN        NaN     NaN      NaN  NaN
# 3  efeU-repair       NaN     NaN     NaN        NaN     NaN      NaN  NaN
# 4      ydcI-KO       NaN     NaN     NaN        NaN     NaN      NaN  NaN
#
#    regulon_size  n_regs                                           Function  \
# 0            11       1                                            Unknown
# 1             9       1                                Glycerol catabolism
# 2             9       1                                   Unknown Function
# 3             8       0  Accounts for repair and expression of efeU operon
# 4             3       0                        Accounts for ydcI knock-out
#
#                     Category
# 0        Regulator Discovery
# ...

# %% [markdown]
# # TRN Table

# %% [markdown]
# ## Load the TRN
# Again, this table can be passed in using either a filename or a pandas DataFrame.

# %%
trn = pd.read_csv(join(DATA_DIR, 'trn.csv'))
ica_data.trn = trn

# %%
ica_data.trn.head()
# Out:
#       regulator  regulator_id  gene_name gene_id effect  ev_level
# 0           FMN           NaN        NaN   b3041      -       NaN
# 1  L-tryptophan           NaN        NaN   b3708      +       NaN
# 2  L-tryptophan           NaN        NaN   b3709      +       NaN
# 3           TPP           NaN        NaN   b0066      -       NaN
# 4           TPP           NaN        NaN   b0067      -       NaN

# %% [markdown]
# # iModulon properties

# %% [markdown]
# ## Inspecting iModulons
# The `view_imodulon` shows the information about each gene in the iModulon. Most information is stored in the `gene_table`, but the `regulator` column comes from the TRN.

# %%
ica_data.view_imodulon(0)
# Out:
#        gene_weight    start     stop strand gene_name  length     operon  \
# b0306     0.237575   321607   322327      +      ykgE     720     ykgEFG
# b0307     0.157379   322337   323765      +      ykgF    1428     ykgEFG
# b0308     0.157886   323757   324453      +      ykgG     696     ykgEFG
# b0447     0.098046   468382   468841      +      ybaO     459       decR
# b1826    -0.124414  1908622  1908766      -      mgrB     144       mgrB
# b2141     0.264099  2230623  2231022      +      yohJ     399      yohJK
# b2142     0.202429  2231018  2231714      +      yohK     696      yohJK
# b2143     0.093723  2231843  2232728      +       cdd     885        cdd
# b3755    -0.348577  3940634  3941327      -      yieP     693  yieP-hsrA
# b4116     0.137769  4337167  4337929      -      adiY     762       adiY
# b4354     0.136132  4589128  4591279      -      yjiY    2151       btsT
#
#                                           cog            regulator
# ...

# %% [markdown]
# ## Renaming iModulons

# %%
# Rename iModulons using a dict
ica_data.rename_imodulons({0:'YieP'})

ica_data.imodulon_table.head()
# Out:
#              name regulator  pvalue  qvalue  precision  recall  f1score   TP  \
# YieP         YieP       NaN     NaN     NaN        NaN     NaN      NaN  NaN
# 1            GlpR      glpR     0.0     NaN        1.0     1.0      4.0  9.0
# 2            YgbI       NaN     NaN     NaN        NaN     NaN      NaN  NaN
# 3     efeU-repair       NaN     NaN     NaN        NaN     NaN      NaN  NaN
# 4         ydcI-KO       NaN     NaN     NaN        NaN     NaN      NaN  NaN
#
#       regulon_size  n_regs                                           Function  \
# YieP            11       1                                            Unknown
# 1                9       1                                Glycerol catabolism
# 2                9       1                                   Unknown Function
# 3                8       0  Accounts for repair and expression of efeU operon
# 4                3       0                        Accounts for ydcI knock-out
#
#                        Category
# ...

# %%
# Rename iModulons using the iModulon table
ica_data.rename_imodulons(column='name')
ica_data.imodulon_table.head()
# Out:
#             regulator  pvalue  qvalue  precision  recall  f1score   TP  \
# name
# YieP              NaN     NaN     NaN        NaN     NaN      NaN  NaN
# GlpR             glpR     0.0     NaN        1.0     1.0      4.0  9.0
# YgbI              NaN     NaN     NaN        NaN     NaN      NaN  NaN
# efeU-repair       NaN     NaN     NaN        NaN     NaN      NaN  NaN
# ydcI-KO           NaN     NaN     NaN        NaN     NaN      NaN  NaN
#
#              regulon_size  n_regs  \
# name
# YieP                   11       1
# GlpR                    9       1
# YgbI                    9       1
# efeU-repair             8       0
# ydcI-KO                 3       0
#
#                                                       Function  \
# name
# YieP                                                   Unknown
# GlpR                                       Glycerol catabolism
# YgbI                                          Unknown Function
# ...

# %%
# This also renames the M and A matrix
ica_data.M.head()
# Out:
# name       YieP      GlpR      YgbI  efeU-repair   ydcI-KO   BW25113  \
# b0002  0.072693 -0.006320 -0.038374    -0.010045 -0.004345 -0.005599
# b0003  0.015975 -0.009969 -0.024571    -0.006775 -0.003583  0.006680
# b0004  0.015319 -0.003808 -0.027018    -0.004455 -0.008418  0.003245
# b0005  0.008229 -0.000685 -0.005215    -0.002029 -0.028069  0.014748
# b0006 -0.004941 -0.001849 -0.002326     0.006075  0.001607  0.009678
#
# name     proVWX  DhaR/Mlc      ArgR      YneJ  ...      RpoS  membrane  \
# b0002  0.009043 -0.005072 -0.012186 -0.013543  ... -0.010152 -0.012124
# b0003 -0.010841 -0.012620 -0.003685  0.003512  ...  0.004702  0.004402
# b0004 -0.016494 -0.013818 -0.008104  0.002144  ...  0.003507  0.005342
# b0005 -0.019240 -0.002403 -0.008507 -0.019092  ... -0.006856  0.010676
# b0006  0.001661  0.003754 -0.000152 -0.001013  ... -0.014761  0.005071
#
# name   duplication-1  uncharacterized-3  ExuR/FucR      FecI  iron-related  \
# ...

# %% [markdown]
# ## Identifying "single-gene" iModulons
# Some iModulons are dominated by a single, high-coefficient gene. These iModulons may result from:
# 1. Overdecomposition of the dataset to identify noisy genes
# 2. Artificial knock-out of single genes
# 3. Regulons with only one target gene
#
# No matter what causes these iModulons, it is important to be aware of them. The `find_single_gene_imodulons` function identifies iModulons that are likely dominated by a single gene.

# %%
ica_data.find_single_gene_imodulons(save=True)
# Out:
# ['ydcI-KO', 'fur-KO', 'Pyruvate', 'thrA-KO', 'sgrT']

# %%
ica_data.imodulon_table.loc[['fur-KO']]
# Out:
#        regulator  pvalue  qvalue  precision  recall  f1score  TP  \
# name
# fur-KO       NaN     NaN     NaN        NaN     NaN      NaN NaN
#
#         regulon_size  n_regs                    Function             Category  \
# name
# fur-KO            13       0  Accounts for fur knock-out  Genomic Alterations
#
#        single_gene
# name
# fur-KO        True

# %% [markdown]
# # Gene set enrichment analysis

# %%
from pymodulon.enrichment import *

# %% [markdown]
# ## General functions

# %% [markdown]
# To perform a basic enrichment test between two samples, use the `compute_enrichment` function.
# Optional arguments:
# * `label`: Label for your target gene set (e.g. regulator name or GO term)

# %%
gene_set = ['b0002','b0003','b0004'] # e.g. an iModulon or other gene set
target_genes = ['b0002','b0005','b0007'] # e.g. a regulon or genes in a COG category
all_genes = ica_data.M.index # List of all genes in your expression dataset

# %%
compute_enrichment(gene_set,target_genes,all_genes)
# Out:
# pvalue             0.002293
# precision          0.333333
# recall             0.333333
# f1score            0.333333
# TP                 1.000000
# target_set_size    3.000000
# gene_set_size      3.000000
# dtype: float64

# %% [markdown]
# To perform an enrichment test against a regulon in a TRN table, use the `compute_regulon` function.

# %%
compute_regulon_enrichment(gene_set,'lrp',all_genes,trn)
# Out:
# /home/anand/PycharmProjects/pymodulon/pymodulon/enrichment.py:125: UserWarning: Some genes are in the regulon but not in all_genes. These genes are removed before enrichment analysis.
#   warn('Some genes are in the regulon but not in all_genes. These genes are removed before enrichment '
# pvalue             0.000131
# precision          0.015000
# recall             1.000000
# f1score            0.029557
# TP                 3.000000
# regulon_size     200.000000
# gene_set_size      3.000000
# n_regs             1.000000
# Name: lrp, dtype: float64

# %% [markdown]
# To perform an enrichment against all regulons in a TRN table, use the `compute_trn_enrichment` function. Optional arguments:
# * `max_regs`: Maximum number of regulators to include in complex regulon (default: 1)
# * `fdr`: False detection rate for Benjamini Hochberg correction
# * `method`: How to combine complex regulons. `'or'` computes enrichment against union of regulons, `'and'` computes enrichment against intersection of regulons, and `'both'` performs both tests (default: `'both'`)
# * `force`: Allows computation of >2 regulators

# %%
compute_trn_enrichment(gene_set,all_genes,trn)
# Out:
#                 pvalue  precision  recall  f1score   TP  regulon_size  \
# thr-tRNA  0.000000e+00   1.000000     1.0      1.0  3.0           3.0
# ile-tRNA  8.354256e-09   0.333333     1.0      0.5  3.0           9.0
#
#           gene_set_size  n_regs    qvalue
# thr-tRNA            3.0     1.0  0.000000
# ile-tRNA            3.0     1.0  0.000002

# %%
compute_trn_enrichment(gene_set,all_genes,trn,max_regs=3)
# Out:
# /home/anand/PycharmProjects/pymodulon/pymodulon/enrichment.py:152: RuntimeWarning: Using >2 maximum regulators may take time to compute. To perform analysis, use force=True
#   warn('Using >2 maximum regulators may take time to compute. To perform analysis, use force=True',

# %%
compute_trn_enrichment(gene_set,all_genes,trn,max_regs=3,force=True).head()
# Out:
# /home/anand/PycharmProjects/pymodulon/pymodulon/enrichment.py:125: UserWarning: Some genes are in the regulon but not in all_genes. These genes are removed before enrichment analysis.
#   warn('Some genes are in the regulon but not in all_genes. These genes are removed before enrichment '
#                     pvalue  precision  recall  f1score   TP  regulon_size  \
# arcA+ile-tRNA+rpoD     0.0        1.0     1.0      1.0  3.0           3.0
# arcA+lrp+thr-tRNA      0.0        1.0     1.0      1.0  3.0           3.0
# arcA+rpoD+thr-tRNA     0.0        1.0     1.0      1.0  3.0           3.0
# crp+fnr+ile-tRNA       0.0        1.0     1.0      1.0  3.0           3.0
# crp+fnr+thr-tRNA       0.0        1.0     1.0      1.0  3.0           3.0
#
#                     gene_set_size  n_regs  qvalue
# arcA+ile-tRNA+rpoD            3.0     3.0     0.0
# arcA+lrp+thr-tRNA             3.0     3.0     0.0
# arcA+rpoD+thr-tRNA            3.0     3.0     0.0
# ...

# %% [markdown]
# ## Using the IcaData object

# %%
# Compare a single iModulon to a simple regulon
ica_data.compute_regulon_enrichment('GlpR',regulator='glpR')
# Out:
# pvalue           0
# precision        1
# recall           1
# f1score          1
# TP               9
# regulon_size     9
# imodulon_size    9
# n_regs           1
# Name: glpR, dtype: int64

# %%
# Compare a single iModulon to a complex regulon
ica_data.compute_regulon_enrichment('Copper','cusR/cueR')
# Out:
# pvalue           5.471346e-20
# precision        4.210526e-01
# recall           1.000000e+00
# f1score          5.925926e-01
# TP               8.000000e+00
# regulon_size     1.900000e+01
# imodulon_size    8.000000e+00
# n_regs           2.000000e+00
# Name: cusR/cueR, dtype: float64

# %%
# Get all significant enrichments for all iModulons. 
# Optional parameters are same as the global compute_trn_enrichment function
ica_data.compute_trn_enrichment()
# Out:
#         imodulon regulator        pvalue        qvalue  precision    recall  \
# 0           GlpR      glpR  0.000000e+00  0.000000e+00   1.000000  1.000000
# 1           GlpR       crp  3.567813e-08  8.420040e-06   0.015332  1.000000
# 2    efeU-repair       fur  2.409711e-09  1.137384e-06   0.040000  0.875000
# 3        BW25113      mhpR  3.603815e-09  1.701001e-06   0.666667  0.235294
# 4       DhaR/Mlc       mlc  1.497841e-11  7.069810e-09   0.500000  0.454545
# ..           ...       ...           ...           ...        ...       ...
# 145         FecI      fecI  3.262855e-14  1.540067e-11   1.000000  0.500000
# 146         FecI       fur  5.508595e-12  1.300028e-09   0.051429  0.900000
# 147         FecI      hypT  4.163677e-11  6.550851e-09   0.384615  0.500000
# 148         FecI      pdhR  2.352987e-08  2.776524e-06   0.121951  0.500000
# 149         RbsR      rbsR  9.780236e-14  4.616271e-11   0.555556  0.833333
#
#       f1score   TP  regulon_size  imodulon_size  n_regs
# ...

# %% [markdown]
# ### Save to sample table
# You can directly save iModulon enrichments to the sample table using either the `ica_data.compute_regulon_enrichment` function or `ica_data.compute_trn_enrichment` function. Columns unrelated to regulon enrichments (e.g. `Function` and `Category`) are left alone.

# %%
ica_data.imodulon_table.loc[['GlpR']]
# Out:
#      regulator  pvalue  qvalue  precision  recall  f1score   TP  regulon_size  \
# name
# GlpR      glpR     0.0     NaN        1.0     1.0      4.0  9.0             9
#
#       n_regs             Function                   Category single_gene
# name
# GlpR       1  Glycerol catabolism  Carbon Source Utilization         NaN

# %%
ica_data.compute_regulon_enrichment('GlpR',regulator='crp',save=True)
ica_data.imodulon_table.loc[['GlpR']]
# Out:
#      regulator        pvalue  qvalue  precision  recall   f1score   TP  \
# name
# GlpR       crp  3.567813e-08     NaN   0.015332     1.0  0.030201  9.0
#
#       regulon_size  n_regs             Function                   Category  \
# name
# GlpR         587.0     1.0  Glycerol catabolism  Carbon Source Utilization
#
#      single_gene  imodulon_size
# name
# GlpR         NaN            9.0

# %%
# The enrichment with the lowest qvalue is saved as the official enrichment
ica_data.compute_trn_enrichment(save=True)
ica_data.imodulon_table
# Out:
#              regulator        pvalue        qvalue  precision    recall  \
# YieP               NaN           NaN           NaN        NaN       NaN
# GlpR              glpR  0.000000e+00  0.000000e+00   1.000000  1.000000
# YgbI               NaN           NaN           NaN        NaN       NaN
# efeU-repair        fur  2.409711e-09  1.137384e-06   0.040000  0.875000
# ydcI-KO            NaN           NaN           NaN        NaN       NaN
# ...                ...           ...           ...        ...       ...
# FecI              fecI  3.262855e-14  1.540067e-11   1.000000  0.500000
# iron-related       NaN           NaN           NaN        NaN       NaN
# RbsR              rbsR  9.780236e-14  4.616271e-11   0.555556  0.833333
# sgrT               NaN           NaN           NaN        NaN       NaN
# insertion          NaN           NaN           NaN        NaN       NaN
#
#                f1score   TP  regulon_size  imodulon_size  n_regs  \
# ...

# %% [markdown]
# # iModulon Thresholds
# iModulon thresholds are computed using an outlier test (See Methods section "*Determination of the gene coefficient threshold*" in [Sastry et al 2019](https://www.nature.com/articles/s41467-019-13483-w#Sec11)). This outlier test relies on the D'agostino test statistic.
# * If you have a relatively complete TRN, you may fit this test statistic using the `reoptimize_thresholds` function.
# * To manually adjust this statistic, use the `recompute_thresholds` function.
# * To change a single iModulon threshold, use the `change_threshold` function.

# %% [markdown]
# ## Fitting the threshold
# The `reoptimize_threshold` function may take a few minutes to complete. Fortunately, this only needs to be performed once. You can turn off the progress bar or plot using the `progress` and `plot` arguments, respectively.

# %%
ica_data.reoptimize_thresholds()
# Out:
# ...
# 600

# %% [markdown]
# ## Changing the D'agostino statistic
# To test out different D'agostino test statistics, use the `recompute_thresholds` function

# %%
ica_data.view_imodulon('GlpR')
# Out:
#        gene_weight    start     stop strand gene_name  length  operon  \
# b2239     0.211384  2349934  2351011      -      glpQ    1077   glpTQ
# b2240     0.306134  2351015  2352374      -      glpT    1359   glpTQ
# b2241     0.375662  2352646  2354275      +      glpA    1629  glpABC
# b2242     0.328961  2354264  2355524      +      glpB    1260  glpABC
# b2243     0.315752  2355520  2356711      +      glpC    1191  glpABC
# b3426     0.350034  3562012  3563518      +      glpD    1506    glpD
# b3925     0.084278  4114568  4115579      -      glpX    1011  glpFKX
# b3926     0.290235  4115713  4117222      -      glpK    1509  glpFKX
# b3927     0.312307  4117244  4118090      -      glpF     846  glpFKX
#
#                                          cog  \
# b2239       Energy production and conversion
# b2240  Carbohydrate transport and metabolism
# b2241       Energy production and conversion
# b2242    Amino acid transport and metabolism
# ...

# %%
ica_data.recompute_thresholds(300)

# %%
ica_data.view_imodulon('GlpR')
# Out:
#        gene_weight    start     stop strand gene_name  length     operon  \
# b1199     0.045686  1249124  1249757      -      dhaL     633     dhaKLM
# b1200     0.045491  1249767  1250838      -      dhaK    1071     dhaKLM
# b2239     0.211384  2349934  2351011      -      glpQ    1077      glpTQ
# b2240     0.306134  2351015  2352374      -      glpT    1359      glpTQ
# b2241     0.375662  2352646  2354275      +      glpA    1629     glpABC
# b2242     0.328961  2354264  2355524      +      glpB    1260     glpABC
# b2243     0.315752  2355520  2356711      +      glpC    1191     glpABC
# b3011     0.049324  3155354  3156518      +      yqhD    1164  yqhD-dkgA
# b3426     0.350034  3562012  3563518      +      glpD    1506       glpD
# b3925     0.084278  4114568  4115579      -      glpX    1011     glpFKX
# b3926     0.290235  4115713  4117222      -      glpK    1509     glpFKX
# b3927     0.312307  4117244  4118090      -      glpF     846     glpFKX
#
# ...

# %% [markdown]
# ## Manually changing thresholds
# To manually change a threshold, use the `change_threshold` function.

# %%
ica_data.change_threshold('GlpR',0.3)

# %%
ica_data.view_imodulon('GlpR')
# Out:
#        gene_weight    start     stop strand gene_name  length  operon  \
# b2240     0.306134  2351015  2352374      -      glpT    1359   glpTQ
# b2241     0.375662  2352646  2354275      +      glpA    1629  glpABC
# b2242     0.328961  2354264  2355524      +      glpB    1260  glpABC
# b2243     0.315752  2355520  2356711      +      glpC    1191  glpABC
# b3426     0.350034  3562012  3563518      +      glpD    1506    glpD
# b3927     0.312307  4117244  4118090      -      glpF     846  glpFKX
#
#                                          cog  \
# b2240  Carbohydrate transport and metabolism
# b2241       Energy production and conversion
# b2242    Amino acid transport and metabolism
# b2243       Energy production and conversion
# b3426       Energy production and conversion
# b3927  Carbohydrate transport and metabolism
#
#                                   regulator
# b2240         crp,fis,fnr,glpR,ihf,nac,rpoD
# b2241  arcA,crp,fis,flhD;flhC,fnr,glpR,rpoD
# ...

# %% [markdown]
# # Plotting

# %%
from pymodulon.visualization import *

# %% [markdown]
# ## Bar plots
# Gene expression and iModulon activities are easily viewed as bar plots. Use the `plot_expression` and `plot_activities` functions, respectively. Any numeric metadata for your experiments can be plotted using the `plot_metadata` function.
#
# Optional arguments:
# * `projects`: Only show specific project(s)
# * `highlight`: Show individiual conditions for specific project(s)
# * `ax`: Use a pre-existing axis (helpful if you want to manually determine the plot size)
# * `legend_args`: Arguments to pass to the legend (e.g. `{'fontsize':12, 'loc':0, 'ncol':2}`)

# %%
ica_data.sample_table = ica_data.sample_table.rename({'project_id':'project','condition_id':'condition'},axis=1)

# %% [markdown]
# ### Plot Gene Expression
# You can plot the compendium-wide expression of a gene using either the locus tag or gene name

# %%
plot_expression(ica_data,'b0002')

# %%
plot_expression(ica_data,'thrA',projects=['ica','fps'],highlight='fps')

# %% [markdown]
# ### Plot iModulon Activities

# %%
plot_activities(ica_data,'GlpR',highlight='crp')

# %% [markdown]
# ### Plot sample metadata

# %%
plot_metadata(ica_data,'Growth Rate (1/hr)')

# %% [markdown]
# ## Scatterplots

# %% [markdown]
# Gene expression and iModulon activities can be compared with a scatter plot. Use the `compare_expression` and `compare_activities` functions, respectively. In addition, `compare_values` can be used to compare any compendium-wide value against another, including gene expression, iModulon activity, and sample metadata.
#
# Optional arguments:
# * `groups`: Mapping of samples to specific groups
# * `show_labels`: Show labels for points. (default: `False`)
# * `adjust_labels`: Automatically avoid label overlap
# * `fit_metric`: Correlation metric of `'pearson'`,`'spearman'`, or `'r2adj'` (default: `'pearson'`)
# * `ax`: Use a pre-existing axis (helpful if you want to manually determine the plot size)
#
# Formatting arguments:
# * `ax_font_args`: Arguments for label axes (e.g. `{'fontsize':16'}`)
# * `scatter_args`: Arguments for scatter plot (e.g. `{'s'=10}`)
# * `label_font_args`: Arguments for text labels (e.g. `{'fontsize':8}`)
# * `legend_args`: Arguments to pass to the legend (e.g. `{'fontsize':12, 'loc':0, 'ncol':2}`)

# %% [markdown]
# ### Compare two iModulon activities

# %%
groups = {'minspan__wt_glc_anaero__1':'Anaerobic',
          'minspan__wt_glc_anaero__2':'Anaerobic'}

# %%
compare_activities(ica_data,'Fnr','ArcA-1',groups=groups)
